# %%
data_dir_path = '/data/examples/flower_classification'

# %%
target_label_file_name = 'mapping.csv'
# /data/examples/may_the_4_be_with_u/where_am_i/mid_term_mapping.txt
target_label_file_path = '/'.join((data_dir_path, target_label_file_name))


import csv
all_lines = dict()
with open(target_label_file_path, newline='') as csvfile:
    all_lines_csv = csv.reader(csvfile, delimiter=',')
    next(all_lines_csv, None)
    for item in all_lines_csv:
        all_lines[item[0]] = item[1]


'''
 for line in all_lines:
    target_class, target_label = line
    target_labels[target_class] = target_label
'''   


all_lines
# Out:
# {'daisy': '0', 'dandelion': '1', 'rose': '2', 'sunflower': '3', 'tulip': '4'}

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("9922116524_ab4a2533fe_n.jpg")
img = img[:,:,::-1]
plt.imshow(img)
plt.show()

# %%
img = cv2.resize(img, (299, 299))
plt.imshow(img)
plt.show()
